# %% [markdown]
# <h1>Tweet Scraper</h1>

# %% [markdown]
# This notebook uses **Tweepy Twitter scrapper** in order to scrape data from twitter.
# **Please notice:** Twitter is making it pretty hard to scraped multiple tweets from thier site.
# **You are limited to 1000 observations per scraping. Also, You might not be able to run all this notebok at once, because twitter will blok you.**
# It's better to scrap 2 line at a time, and than restart the karnel. That is why I split it this way.
# Also, notice that you are not puting to much key words in the searching line.

# %% [markdown]
# ## Negative tweets

# %%
neg_line1 = "#IDoNotConsent OR #IWillNOTComply OR OR #Idonotconsent OR #novaccine OR #idonotconsen OR #AntiVacciners"
neg_line2 = "antivaxx OR #antivaxxers OR #Antivaxx OR #TrumpsVaccineIsALie OR #antivax OR #CovidHoax OR #antivaxx OR #antivaxers"

# %%
import tweepy as tw
import pandas as pd

auth = tw.OAuthHandler('d5HZe4mtTtZDAJllEnbuyaT9v', 'mY7Jlf9r1j3BOI20QSB84T3ktByMxjwjAhL6rrRRjrBckBShE0')
auth.set_access_token('230756541-J0P9NtPULFfEebC5mOQoB1k4n6dJwd7yk8NPGjHd', 'DY0UlIsKTG6FX7AuQVUCTQx248Mbta8J76FuSyHTMezDB')
api = tw.API(auth)
date_since = "2021-01-01"
date_until= "2021-01-10"

# %%
search_words = neg_line1

tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(1000)
content = []
id = []
username = []
location = []
description = []
user_creat_date = []
followers = []
favorite_tweet_count = []
retweet_count = []
posted_at = []
is_retweet = []

for i, tweet in enumerate(tweets):
    print(i)
    content.append(tweet.text)
    id.append(tweet.id)
    username.append(tweet.user.screen_name)
    location.append(tweet.user.location)
    description.append(tweet.user.description)
    user_creat_date.append(tweet.user.created_at)
    followers.append(tweet.user.followers_count)
    favorite_tweet_count.append(tweet.favorite_count)
    retweet_count.append(tweet.retweet_count)
    posted_at.append(tweet.created_at)
    is_retweet.append(tweet.retweet_count > 0)
    
data = {'id': id,
        'user_name': username,
        'user_location':location,
        'user_description':description,
        'user_created': user_creat_date,
        'user_followers':followers,
        'date':posted_at,
        'text':content,
        'favorites':favorite_tweet_count,
        'retweets':retweet_count,
        'is_retweet':is_retweet
        }

neg1 = pd.DataFrame(data)
print(neg1.shape)
df.head()

# %%
search_words = neg_line2

tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(1000)
content = []
id = []
username = []
location = []
description = []
user_creat_date = []
followers = []
favorite_tweet_count = []
retweet_count = []
posted_at = []
is_retweet = []

for i, tweet in enumerate(tweets):
    print(i)
    content.append(tweet.text)
    id.append(tweet.id)
    username.append(tweet.user.screen_name)
    location.append(tweet.user.location)
    description.append(tweet.user.description)
    user_creat_date.append(tweet.user.created_at)
    followers.append(tweet.user.followers_count)
    favorite_tweet_count.append(tweet.favorite_count)
    retweet_count.append(tweet.retweet_count)
    posted_at.append(tweet.created_at)
    is_retweet.append(tweet.retweet_count > 0)
    
data = {'id': id,
        'user_name': username,
        'user_location':location,
        'user_description':description,
        'user_created': user_creat_date,
        'user_followers':followers,
        'date':posted_at,
        'text':content,
        'favorites':favorite_tweet_count,
        'retweets':retweet_count,
        'is_retweet':is_retweet
        }

neg2 = pd.DataFrame(data)
print(neg2.shape)
df.head()

# %%
df = pd.concat([neg1 ,neg2], ignore_index=True)
print(df.shape)
df.head()

# %%
df.to_csv("negative_df1.csv")

# %%
neg_line3 = "#AntiVaxxers OR #antivaccers OR #anticovid OR #antivaccine"
neg_line4 = "#fakenews OR #antivaxxer OR #AntiScience OR #CovidDeniers"

# %%
import tweepy as tw
import pandas as pd

auth = tw.OAuthHandler('d5HZe4mtTtZDAJllEnbuyaT9v', 'mY7Jlf9r1j3BOI20QSB84T3ktByMxjwjAhL6rrRRjrBckBShE0')
auth.set_access_token('230756541-J0P9NtPULFfEebC5mOQoB1k4n6dJwd7yk8NPGjHd', 'DY0UlIsKTG6FX7AuQVUCTQx248Mbta8J76FuSyHTMezDB')
api = tw.API(auth)
date_since = "2021-01-01"
date_until= "2021-01-10"

# %%
search_words = neg_line3

tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(1000)
content = []
id = []
username = []
location = []
description = []
user_creat_date = []
followers = []
favorite_tweet_count = []
retweet_count = []
posted_at = []
is_retweet = []

for i, tweet in enumerate(tweets):
    print(i)
    content.append(tweet.text)
    id.append(tweet.id)
    username.append(tweet.user.screen_name)
    location.append(tweet.user.location)
    description.append(tweet.user.description)
    user_creat_date.append(tweet.user.created_at)
    followers.append(tweet.user.followers_count)
    favorite_tweet_count.append(tweet.favorite_count)
    retweet_count.append(tweet.retweet_count)
    posted_at.append(tweet.created_at)
    is_retweet.append(tweet.retweet_count > 0)
    
data = {'id': id,
        'user_name': username,
        'user_location':location,
        'user_description':description,
        'user_created': user_creat_date,
        'user_followers':followers,
        'date':posted_at,
        'text':content,
        'favorites':favorite_tweet_count,
        'retweets':retweet_count,
        'is_retweet':is_retweet
        }

neg3 = pd.DataFrame(data)
print(neg3.shape)

# %%
search_words = neg_line4

tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(1000)
content = []
id = []
username = []
location = []
description = []
user_creat_date = []
followers = []
favorite_tweet_count = []
retweet_count = []
posted_at = []
is_retweet = []

for i, tweet in enumerate(tweets):
    print(i)
    content.append(tweet.text)
    id.append(tweet.id)
    username.append(tweet.user.screen_name)
    location.append(tweet.user.location)
    description.append(tweet.user.description)
    user_creat_date.append(tweet.user.created_at)
    followers.append(tweet.user.followers_count)
    favorite_tweet_count.append(tweet.favorite_count)
    retweet_count.append(tweet.retweet_count)
    posted_at.append(tweet.created_at)
    is_retweet.append(tweet.retweet_count > 0)
    
data = {'id': id,
        'user_name': username,
        'user_location':location,
        'user_description':description,
        'user_created': user_creat_date,
        'user_followers':followers,
        'date':posted_at,
        'text':content,
        'favorites':favorite_tweet_count,
        'retweets':retweet_count,
        'is_retweet':is_retweet
        }

neg4 = pd.DataFrame(data)
print(neg4.shape)
neg4.head()

# %%
df2 = pd.concat([neg3 ,neg4], ignore_index=True)
print(df2.shape)
df2.head()

# %%
df2.to_csv("negative_df2.csv")

# %%
neg_line5 = "#AntiVaxxers OR #antivaccers OR #anticovid OR #antivaccine"
neg_line6 = "#fakenews OR #antivaxxer OR #AntiScience OR #CovidDeniers"

# %%
import tweepy as tw
import pandas as pd

auth = tw.OAuthHandler('d5HZe4mtTtZDAJllEnbuyaT9v', 'mY7Jlf9r1j3BOI20QSB84T3ktByMxjwjAhL6rrRRjrBckBShE0')
auth.set_access_token('230756541-J0P9NtPULFfEebC5mOQoB1k4n6dJwd7yk8NPGjHd', 'DY0UlIsKTG6FX7AuQVUCTQx248Mbta8J76FuSyHTMezDB')
api = tw.API(auth)
date_since = "2021-01-01"
date_until= "2021-01-10"

# %%
search_words = neg_line5

tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(1000)
content = []
id = []
username = []
location = []
description = []
user_creat_date = []
followers = []
favorite_tweet_count = []
retweet_count = []
posted_at = []
is_retweet = []

for i, tweet in enumerate(tweets):
    print(i)
    content.append(tweet.text)
    id.append(tweet.id)
    username.append(tweet.user.screen_name)
    location.append(tweet.user.location)
    description.append(tweet.user.description)
    user_creat_date.append(tweet.user.created_at)
    followers.append(tweet.user.followers_count)
    favorite_tweet_count.append(tweet.favorite_count)
    retweet_count.append(tweet.retweet_count)
    posted_at.append(tweet.created_at)
    is_retweet.append(tweet.retweet_count > 0)
    
data = {'id': id,
        'user_name': username,
        'user_location':location,
        'user_description':description,
        'user_created': user_creat_date,
        'user_followers':followers,
        'date':posted_at,
        'text':content,
        'favorites':favorite_tweet_count,
        'retweets':retweet_count,
        'is_retweet':is_retweet
        }

neg5 = pd.DataFrame(data)
print(neg5.shape)
neg5.head()

# %%
search_words = neg_line6

tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(1000)
content = []
id = []
username = []
location = []
description = []
user_creat_date = []
followers = []
favorite_tweet_count = []
retweet_count = []
posted_at = []
is_retweet = []

for i, tweet in enumerate(tweets):
    print(i)
    content.append(tweet.text)
    id.append(tweet.id)
    username.append(tweet.user.screen_name)
    location.append(tweet.user.location)
    description.append(tweet.user.description)
    user_creat_date.append(tweet.user.created_at)
    followers.append(tweet.user.followers_count)
    favorite_tweet_count.append(tweet.favorite_count)
    retweet_count.append(tweet.retweet_count)
    posted_at.append(tweet.created_at)
    is_retweet.append(tweet.retweet_count > 0)
    
data = {'id': id,
        'user_name': username,
        'user_location':location,
        'user_description':description,
        'user_created': user_creat_date,
        'user_followers':followers,
        'date':posted_at,
        'text':content,
        'favorites':favorite_tweet_count,
        'retweets':retweet_count,
        'is_retweet':is_retweet
        }

neg6 = pd.DataFrame(data)
print(neg6.shape)
neg6.head()

# %%
df3 = pd.concat([neg5 ,neg6], ignore_index=True)
print(df3.shape)
df3.head()

# %%
df3.to_csv("negative_df3.csv")

# %%
neg_line7 = "#pseudoscience OR #antivaccinepropaganda OR #novaccine OR #nonewnormal"
neg_line8 = "#NoMandatoryVaccine OR #NoVaccine OR #nojabnoplay"

# %%
import tweepy as tw
import pandas as pd

auth = tw.OAuthHandler('d5HZe4mtTtZDAJllEnbuyaT9v', 'mY7Jlf9r1j3BOI20QSB84T3ktByMxjwjAhL6rrRRjrBckBShE0')
auth.set_access_token('230756541-J0P9NtPULFfEebC5mOQoB1k4n6dJwd7yk8NPGjHd', 'DY0UlIsKTG6FX7AuQVUCTQx248Mbta8J76FuSyHTMezDB')
api = tw.API(auth)
date_since = "2021-01-01"
date_until= "2021-01-10"

# %%
search_words = neg_line7

tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(1000)
content = []
id = []
username = []
location = []
description = []
user_creat_date = []
followers = []
favorite_tweet_count = []
retweet_count = []
posted_at = []
is_retweet = []

for i, tweet in enumerate(tweets):
    print(i)
    content.append(tweet.text)
    id.append(tweet.id)
    username.append(tweet.user.screen_name)
    location.append(tweet.user.location)
    description.append(tweet.user.description)
    user_creat_date.append(tweet.user.created_at)
    followers.append(tweet.user.followers_count)
    favorite_tweet_count.append(tweet.favorite_count)
    retweet_count.append(tweet.retweet_count)
    posted_at.append(tweet.created_at)
    is_retweet.append(tweet.retweet_count > 0)
    
data = {'id': id,
        'user_name': username,
        'user_location':location,
        'user_description':description,
        'user_created': user_creat_date,
        'user_followers':followers,
        'date':posted_at,
        'text':content,
        'favorites':favorite_tweet_count,
        'retweets':retweet_count,
        'is_retweet':is_retweet
        }

neg7 = pd.DataFrame(data)
print(neg7.shape)
neg7.head()

# %%
search_words = neg_line8

tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(1000)
content = []
id = []
username = []
location = []
description = []
user_creat_date = []
followers = []
favorite_tweet_count = []
retweet_count = []
posted_at = []
is_retweet = []

for i, tweet in enumerate(tweets):
    print(i)
    content.append(tweet.text)
    id.append(tweet.id)
    username.append(tweet.user.screen_name)
    location.append(tweet.user.location)
    description.append(tweet.user.description)
    user_creat_date.append(tweet.user.created_at)
    followers.append(tweet.user.followers_count)
    favorite_tweet_count.append(tweet.favorite_count)
    retweet_count.append(tweet.retweet_count)
    posted_at.append(tweet.created_at)
    is_retweet.append(tweet.retweet_count > 0)
    
data = {'id': id,
        'user_name': username,
        'user_location':location,
        'user_description':description,
        'user_created': user_creat_date,
        'user_followers':followers,
        'date':posted_at,
        'text':content,
        'favorites':favorite_tweet_count,
        'retweets':retweet_count,
        'is_retweet':is_retweet
        }

neg8 = pd.DataFrame(data)
print(neg8.shape)
neg8.head()

# %%
df4 = pd.concat([neg7 ,neg8], ignore_index=True)
print(df4.shape)
df4.head()

# %%
df4.to_csv("negative_df4.csv")

# %%
neg_line9 = "#prochoice OR #youtakeitfirst OR #noway OR #novaccines OR #covidscam OR #NotYourCovidGuineaPig"

# %%
import tweepy as tw
import pandas as pd

auth = tw.OAuthHandler('d5HZe4mtTtZDAJllEnbuyaT9v', 'mY7Jlf9r1j3BOI20QSB84T3ktByMxjwjAhL6rrRRjrBckBShE0')
auth.set_access_token('230756541-J0P9NtPULFfEebC5mOQoB1k4n6dJwd7yk8NPGjHd', 'DY0UlIsKTG6FX7AuQVUCTQx248Mbta8J76FuSyHTMezDB')
api = tw.API(auth)
date_since = "2021-01-01"
date_until= "2021-01-10"

# %%
search_words = neg_line9

tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(1000)
content = []
id = []
username = []
location = []
description = []
user_creat_date = []
followers = []
favorite_tweet_count = []
retweet_count = []
posted_at = []
is_retweet = []

for i, tweet in enumerate(tweets):
    print(i)
    content.append(tweet.text)
    id.append(tweet.id)
    username.append(tweet.user.screen_name)
    location.append(tweet.user.location)
    description.append(tweet.user.description)
    user_creat_date.append(tweet.user.created_at)
    followers.append(tweet.user.followers_count)
    favorite_tweet_count.append(tweet.favorite_count)
    retweet_count.append(tweet.retweet_count)
    posted_at.append(tweet.created_at)
    is_retweet.append(tweet.retweet_count > 0)
    
data = {'id': id,
        'user_name': username,
        'user_location':location,
        'user_description':description,
        'user_created': user_creat_date,
        'user_followers':followers,
        'date':posted_at,
        'text':content,
        'favorites':favorite_tweet_count,
        'retweets':retweet_count,
        'is_retweet':is_retweet
        }

neg9 = pd.DataFrame(data)
print(neg9.shape)
neg9.head()

# %%
neg9.to_csv("negative_df5.csv")

# %% [markdown]
# ## Positive tweets

# %%
pos_line1 = "#unmaskourkids OR #IGotTheShot OR #igottheshot"
pos_line2= "#ThisIsOurShot OR #trustinscience OR #GetVaccinated OR#VaccinesSaveLives"

# %%
import tweepy as tw
import pandas as pd

auth = tw.OAuthHandler('d5HZe4mtTtZDAJllEnbuyaT9v', 'mY7Jlf9r1j3BOI20QSB84T3ktByMxjwjAhL6rrRRjrBckBShE0')
auth.set_access_token('230756541-J0P9NtPULFfEebC5mOQoB1k4n6dJwd7yk8NPGjHd', 'DY0UlIsKTG6FX7AuQVUCTQx248Mbta8J76FuSyHTMezDB')
api = tw.API(auth)
date_since = "2021-01-01"
date_until= "2021-01-10"

# %%
search_words = pos_line1

tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(1000)
content = []
id = []
username = []
location = []
description = []
user_creat_date = []
followers = []
favorite_tweet_count = []
retweet_count = []
posted_at = []
is_retweet = []

for i, tweet in enumerate(tweets):
    print(i)
    content.append(tweet.text)
    id.append(tweet.id)
    username.append(tweet.user.screen_name)
    location.append(tweet.user.location)
    description.append(tweet.user.description)
    user_creat_date.append(tweet.user.created_at)
    followers.append(tweet.user.followers_count)
    favorite_tweet_count.append(tweet.favorite_count)
    retweet_count.append(tweet.retweet_count)
    posted_at.append(tweet.created_at)
    is_retweet.append(tweet.retweet_count > 0)
    
data = {'id': id,
        'user_name': username,
        'user_location':location,
        'user_description':description,
        'user_created': user_creat_date,
        'user_followers':followers,
        'date':posted_at,
        'text':content,
        'favorites':favorite_tweet_count,
        'retweets':retweet_count,
        'is_retweet':is_retweet
        }

pos1 = pd.DataFrame(data)
print(pos1.shape)
pos1.head()

# %%
search_words = pos_line2

tweets = tw.Cursor(api.search,
              q=search_words,
              lang="en",
              since=date_since).items(1000)
content = []
id = []
username = []
location = []
description = []
user_creat_date = []
followers = []
favorite_tweet_count = []
retweet_count = []
posted_at = []
is_retweet = []

for i, tweet in enumerate(tweets):
    print(i)
    content.append(tweet.text)
    id.append(tweet.id)
    username.append(tweet.user.screen_name)
    location.append(tweet.user.location)
    description.append(tweet.user.description)
    user_creat_date.append(tweet.user.created_at)
    followers.append(tweet.user.followers_count)
    favorite_tweet_count.append(tweet.favorite_count)
    retweet_count.append(tweet.retweet_count)
    posted_at.append(tweet.created_at)
    is_retweet.append(tweet.retweet_count > 0)
    
data = {'id': id,
        'user_name': username,
        'user_location':location,
        'user_description':description,
        'user_created': user_creat_date,
        'user_followers':followers,
        'date':posted_at,
        'text':content,
        'favorites':favorite_tweet_count,
        'retweets':retweet_count,
        'is_retweet':is_retweet
        }

# %%
pos2 = pd.DataFrame(data)
print(pos2.shape)
pos2.head()

# %%
df_pos1 = pd.concat([pos1 ,pos1], ignore_index=True)
print(df_pos1.shape)
df_pos1.head()

# %%
df_pos1.to_csv("df_pos1.csv")

# %% [markdown]
# ## Connecting the DF

# %%
df_neg1 = pd.read_csv(r"C:\Users\ronle\Desktop\ITC\course\Data_science_project\Corona\tweet_scraper\negative_df1.csv")
df_neg2 = pd.read_csv(r"C:\Users\ronle\Desktop\ITC\course\Data_science_project\Corona\tweet_scraper\negative_df2.csv")
df_neg3 = pd.read_csv(r"C:\Users\ronle\Desktop\ITC\course\Data_science_project\Corona\tweet_scraper\negative_df3.csv")
df_neg4 =pd.read_csv(r"C:\Users\ronle\Desktop\ITC\course\Data_science_project\Corona\tweet_scraper\negative_df4.csv")
df_neg5 = pd.read_csv(r"C:\Users\ronle\Desktop\ITC\course\Data_science_project\Corona\tweet_scraper\negative_df5.csv")
df_pos1 = pd.read_csv(r"C:\Users\ronle\Desktop\ITC\course\Data_science_project\Corona\tweet_scraper\df_pos1.csv")

# %%
df_neg = pd.concat([df_neg1 ,df_neg2, df_neg3, df_neg4, df_neg5], ignore_index=True)
df_neg['category'] = "Negative"
df_neg.head()

# %%
df_pos1['category'] = "Positive"
df_pos1.head()

# %%
pos_and_neg_tweets = pd.concat([df_pos1, df_neg], ignore_index=True)
pos_and_neg_tweets.to_csv("pos_and_neg_tweets.csv")
